# %% [markdown]
# This tutorial will identify a published SPARC data set (SDS) that uses a python script to generate a derived dataset.
#
# ##data is sourced from https://sparc.science/datasets/262?type=dataset
# ##executed with python 3.10
#
# ## Requirements
# pip install sparc_me
# pip install pyeCAP
# # Using sparc_me to download an existing curated SDS

# %%
from sparc_me import Dataset_Api
api_tools = Dataset_Api()

dataset = api_tools.get_dataset_latest_version_pensieve(262)

# %% [markdown]
# Sparc_me allows us to verify that we have identified the correct data set by simply inspecting the name of the dataset

# %%
dataset
# Out:
# {'id': 262,
#  'sourceDatasetId': 1595,
#  'name': 'Electrode design characterization for electrophysiology from swine peripheral nervous system',
#  'description': 'Comparison of cuff, microelectrode, and intrafascicular electrode to make evoked compound action potential (ECAP) and naturally occurring activity recordings from the peripheral nervous system. Dataset from pigs (n=3) - a human-scale large animal model.',
#  'ownerId': 833,
#  'ownerFirstName': 'Kip',
#  'ownerLastName': 'Ludwig',
#  'ownerOrcid': '0000-0003-4889-1941',
#  'organizationName': 'SPARC Consortium',
#  'organizationId': 367,
#  'license': 'Creative Commons Attribution',
#  'tags': ['electrode design', 'electrophysiology', 'vagus nerve stimulation'],
#  'version': 1,
#  'revision': None,
#  'size': 29634047863,
#  'modelCount': [{'modelName': 'researcher', 'count': 2},
#   {'modelName': 'human_subject', 'count': 0},
#   {'modelName': 'animal_subject', 'count': 6},
#   {'modelName': 'sample', 'count': 0},
#   {'modelName': 'term', 'count': 1},
#   {'modelName': 'award', 'count': 1},
#   {'modelName': 'protocol', 'count': 1},
#   {'modelName': 'summary', 'count': 5}],
#  'fileCount': 722,
#  'recordCount': 16,
#  'uri': 's3://pennsieve-prod-discover-publish-use1/262/1/',
#  'arn': 'arn:aws:s3:::pennsieve-prod-discover-publish-use1/262/1/',
#  'status': 'PUBLISH_SUCCEEDED',
#  'doi': '10.26275/vm1h-k4kq',
#  'banner': 'https://assets.discover.pennsieve.io/dataset-assets/262/1/banner.jpg',
#  'readme': 'https://assets.discover.pennsieve.io/dataset-assets/262/1/readme.md',
#  'contributors': [{'firstName': 'Kip',
#    'middleInitial': 'A',
#    'lastName': 'Ludwig',
#    'degree': 'Ph.D.',
#    'orcid': '0000-0003-4889-1941'},
#   {'firstName': 'Nishant',
#    'middleInitial': None,
#    'lastName': 'Verma',
#    'degree': None,
#    'orcid': '0000-0002-7657-0275'}],
#  'collections': [{'id': 279,
#    'name': 'Electrode design characterization for electrophysiology from peripheral nervous system'}],
#  'externalPublications': [{'doi': '10.17504/protocols.io.j8nlkk6n5l5r/v1',
#    'relationshipType': 'IsSupplementedBy'}],
#  'sponsorship': None,
#  'pennsieveSchemaVersion': '4.0',
#  'createdAt': '2022-07-14T21:39:41.592068Z',
#  'updatedAt': '2023-08-06T00:10:29.809183Z',
#  'firstPublishedAt': '2022-07-14T21:39:41.586248Z',
#  'versionPublishedAt': '2022-07-14T21:39:41.592068Z',
#  'revisedAt': None,
#  'embargo': False,
#  'embargoReleaseDate': '2022-07-07',
#  'embargoAccess': None}

# %%
dataset["name"]
# Out:
# 'Electrode design characterization for electrophysiology from swine peripheral nervous system'

# %% [markdown]
# From this dataset we are interested in sub-1. We can use sparc_me to download the subject data.

# %%
#api_tools.download_dataset(dataset["id"])

# %% [markdown]
# The published SDS included a python file to process the raw recordings, a modified version of this has been included.

# %%
# %run -i "Tutorial 1 data processing.py"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyecap-0.0.1-py3.9.egg\pyeCAP\base\ts_data.py:6: DeprecationWarning:Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\__init__.py:51: DeprecationWarning:invalid escape sequence \W
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:83: DeprecationWarning:invalid escape sequence \[
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:232: DeprecationWarning:invalid escape sequence \d
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:233: DeprecationWarning:invalid escape sequence \d
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:234: DeprecationWarning:invalid escape sequence \d
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:1097: DeprecationWarning:invalid escape sequence \[
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\TDTbin2py.py:1103: DeprecationWarning:invalid escape sequence \s
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\PynapseUDP.py:26: DeprecationWarning:invalid escape sequence \[
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\PynapseUDP.py:27: DeprecationWarning:invalid escape sequence \[
# C:\ProgramData\Anaconda3\lib\site-packages\tdt-0.5.9-py3.9.egg\tdt\PynapseUDP.py:28: DeprecationWarning:invalid escape sequence \s
# C:\ProgramData\Anaconda3\lib\site-packages\pyecap-0.0.1-py3.9.egg\pyeCAP\ecap.py:61: UserWarning:Neural channels not implicitly stated. Assuming all channels are neural recordings
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\overlap.py:654: FutureWarning:The use of map_overlap(array, func, **kwargs) is deprecated since dask 2.17.0 and will be an error in a future release. To silence this warning, use the syntax map_overlap(func, array0,[ array1, ...,] **kwargs) instead.
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\overlap.py:654: FutureWarning:The use of map_overlap(array, func, **kwargs) is deprecated since dask 2.17.0 and will be an error in a future release. To silence this warning, use the syntax map_overlap(func, array0,[ array1, ...,] **kwargs) instead.
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\overlap.py:654: FutureWarning:The use of map_overlap(array, func, **kwargs) is deprecated since dask 2.17.0 and will be an error in a future release. To silence this warning, use the syntax map_overlap(func, array0,[ array1, ...,] **kwargs) instead.
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\overlap.py:654: FutureWarning:The use of map_overlap(array, func, **kwargs) is deprecated since dask 2.17.0 and will be an error in a future release. To silence this warning, use the syntax map_overlap(func, array0,[ array1, ...,] **kwargs) instead.
# C:\ProgramData\Anaconda3\lib\site-packages\pyecap-0.0.1-py3.9.egg\pyeCAP\ecap.py:61: UserWarning:Neural channels not implicitly stated. Assuming all channels are neural recordings
# ['maco 1', 'maco 2', 'maco 3', 'maco 4', 'maco 5', 'maco 6', 'mico 1', 'mico 2', 'mico 3']
